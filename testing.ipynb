# %%
response = await agent.ainvoke({"messages": [{"role": "user", "content": "how many repos are there in my github account?"}]})
print(response["messages"][-1].content)
# Out:
# You currently have **8 public repositories** on your GitHub account (**ViniciusKos**).
#
# If you meant *total repositories including private*, I can’t see that from the public profile—tell me whether you want public-only or total (public + private) and I’ll guide you to where GitHub shows the total.

# %%
import gradio as gr
from langchain.messages import AIMessage, HumanMessage  



async def predict(message, history):
    history_langchain_format = []
    for msg in history:
        if msg["role"] == "user":
            history_langchain_format.append(HumanMessage(content=msg["content"]))
        elif msg["role"] == "assistant":
            history_langchain_format.append(AIMessage(content=msg["content"]))
    history_langchain_format.append(HumanMessage(content=message))
    gpt_response = await agent.ainvoke({"messages": history_langchain_format})
    return gpt_response["messages"][-1].content


demo = gr.ChatInterface(
    predict,
    api_name="chat",
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7866
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7866/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "d:\Vinicius\Projects\llm_with_mcp_client\.venv\Lib\site-packages\gradio\chat_interface.py", line 951, in _stream_fn
#     first_response = await utils.async_iteration(generator)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Vinicius\Projects\llm_with_mcp_client\.venv\Lib\site-packages\gradio\utils.py", line 865, in async_iteration
#     return await anext(iterator)
#            ^^^^^^^^^^^^^^^^^^^^^
# StopAsyncIteration
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "d:\Vinicius\Projects\llm_with_mcp_client\.venv\Lib\site-packages\gradio\queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#     )
#     ^
#   File "d:\Vinicius\Projects\llm_with_mcp_client\.venv\Lib\site-packages\gradio\route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<11 lines>...
#     )
#     ^
#   File "d:\Vinicius\Projects\llm_with_mcp_client\.venv\Lib\site-packages\gradio\blocks.py", line 2158, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<8 lines>...
#     )
#     ^
#   File "d:\Vinicius\Projects\llm_with_mcp_client\.venv\Lib\site-packages\gradio\blocks.py", line 1646, in call_function
#     prediction = await utils.async_iteration(iterator)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Vinicius\Projects\llm_with_mcp_client\.venv\Lib\site-packages\gradio\utils.py", line 865, in async_iteration
#     return await anext(iterator)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Vinicius\Projects\llm_with_mcp_client\.venv\Lib\site-packages\gradio\utils.py", line 990, in asyncgen_wrapper
#     response = await iterator.__anext__()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\Vinicius\Projects\llm_with_mcp_client\.venv\Lib\site-packages\gradio\chat_interface.py", line 536, in _wrapper
#     async for chunk in submit_fn(*args, **kwargs):
#         yield chunk
# RuntimeError: async generator raised StopAsyncIteration
