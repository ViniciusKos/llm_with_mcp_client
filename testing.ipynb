# %%
from langchain.agents import create_agent

from langchain.messages import SystemMessage, HumanMessage


tools = []
agent = create_agent(
    "openai:gpt-5.2",
    tools  
)

# %%
agent.invoke(
    {"messages": [HumanMessage("Analyze the major themes in 'Pride and Prejudice'.")]})
# Out:
# {'messages': [HumanMessage(content="Analyze the major themes in 'Pride and Prejudice'.", additional_kwargs={}, response_metadata={}, id='202f0ef5-b69d-48c7-8489-4dd7a56d99b4'),
#   AIMessage(content='## Major themes in *Pride and Prejudice*\n\n### 1) Marriage as a social and economic institution\nAusten presents marriage not simply as romance but as a practical arrangement shaped by money, class, and women’s limited options. The Bennet sisters’ futures depend on marrying well because of entailment (Longbourn cannot pass to them). Through different couples, Austen surveys motives for marriage:\n- **Charlotte Lucas and Mr. Collins**: security and stability over love.\n- **Lydia and Wickham**: impulsive desire and social scandal.\n- **Jane and Bingley**: affection aligned with social suitability.\n- **Elizabeth and Darcy**: love that requires personal growth and mutual respect.\n\n### 2) Class, status, and social mobility\nThe novel scrutinizes England’s class system—who counts as “gentleman,” what “good breeding” means, and how rank governs behavior. Characters police boundaries constantly (Lady Catherine, the Bingley sisters), while others navigate them:\n- Darcy’s initial pride reflects class consciousness.\n- Elizabeth’s resistance to snobbery challenges the assumption that status equals worth.\nAusten suggests class is powerful and real, but not a reliable measure of virtue.\n\n### 3) Pride, prejudice, and the danger of first impressions\nThe title points to the mutual misunderstandings that shape the plot:\n- **Darcy’s pride** (social superiority, reserve) leads him to act coldly and to interfere with Bingley/Jane.\n- **Elizabeth’s prejudice** (quick judgments, wounded vanity) makes her trust Wickham and misread Darcy.\nThe novel argues that first impressions are often self-serving narratives; growth requires reassessing evidence and motives.\n\n### 4) Individual moral growth and self-knowledge\nAusten frames the central love story as an education in character. Elizabeth and Darcy become better versions of themselves:\n- Elizabeth learns intellectual humility—she can be perceptive yet wrong.\n- Darcy learns empathy and social responsibility, translating feeling into action (especially in handling the Wickham/Lydia crisis).\nLove is portrayed as sustainable only when paired with self-correction and ethical maturity.\n\n### 5) Gender, power, and women’s vulnerability\nWomen’s dependency underpins the stakes of the story. With limited inheritance rights and few respectable careers, marriage becomes tied to survival and reputation:\n- Mrs. Bennet’s anxiety is exaggerated but rooted in real precarity.\n- Lydia’s elopement shows how quickly a woman’s social standing can be ruined—and how little agency she has once compromised.\nAusten also explores women’s voices and constraints: Elizabeth’s wit and refusal to marry without respect is radical within her context, but still bounded by social reality.\n\n### 6) Reputation, propriety, and the surveillance of society\nThe community’s constant observation shapes behavior. “Impropriety” carries serious consequences, especially for women. The militia, balls, visits, and letters create a world where rumor and appearance can determine marriage prospects and family honor. Darcy’s intervention highlights how reputation functions like social currency.\n\n### 7) Family, upbringing, and the shaping of character\nThe Bennet household illustrates how parenting affects outcomes:\n- Mr. Bennet’s detachment and Mrs. Bennet’s nerves foster disorder.\n- Lydia’s lack of guidance contrasts with Elizabeth and Jane’s steadier judgment.\nAusten suggests that character is personal, but family culture strongly influences it.\n\n### 8) Wealth and the moral meaning (or meaninglessness) of money\nMoney drives plot mechanics—entails, dowries, incomes—yet Austen resists making wealth automatically virtuous or corrupt:\n- Wickham’s charm plus financial irresponsibility is dangerous.\n- Darcy’s wealth gives him power, but his moral worth depends on how he uses it.\nThe novel critiques both mercenary marriage and naive romanticism that ignores economic realities.\n\nIf you want, I can organi ...
